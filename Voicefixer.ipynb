# %%
# !pip install git+https://github.com/haoheliu/voicefixer.git pedalboard soundfile librosa
# Out:
# Collecting git+https://github.com/haoheliu/voicefixer.git
#   Cloning https://github.com/haoheliu/voicefixer.git to /tmp/pip-req-build-u5qzxi91
#   Running command git clone --filter=blob:none --quiet https://github.com/haoheliu/voicefixer.git /tmp/pip-req-build-u5qzxi91
#   Resolved https://github.com/haoheliu/voicefixer.git to commit aae2253c85f97a87b844b6832384de249c23ab37
#   Preparing metadata (setup.py) ... done
# Collecting pedalboard
#   Downloading pedalboard-0.9.23-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from voicefixer==0.1.2) (3.10.0)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from voicefixer==0.1.2) (2.11.0+cu128)
# Collecting progressbar (from voicefixer==0.1.2)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torchlibrosa (from voicefixer==0.1.2)
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from voicefixer==0.1.2) (3.1.50)
# Collecting streamlit>=1.12.0 (from voicefixer==0.1.2)
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from voicefixer==0.1.2) (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pedalboard) (2.0.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (26.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.9.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (8.4.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.12.0->voicefixer==0.1.2)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (0.10.2)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (0.52.1)
# Requirement already satisfied: uvicorn>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (0.47.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (0.7.1)
# Requirement already satisfied: anyio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (0.0.29)
# Requirement already satisfied: websockets>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.12.0->voicefixer==0.1.2) (6.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->voicefixer==0.1.2) (4.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (3.29.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->voicefixer==0.1.2) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->voicefixer==0.1.2) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->voicefixer==0.1.2) (2.9.0.post0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (2.21.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.0.0->streamlit>=1.12.0->voicefixer==0.1.2) (3.15)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.7.0->voicefixer==0.1.2) (1.5.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->voicefixer==0.1.2) (5.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit>=1.12.0->voicefixer==0.1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=1.4.0->streamlit>=1.12.0->voicefixer==0.1.2) (2026.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.0->voicefixer==0.1.2) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->voicefixer==0.1.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.5.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.0->voicefixer==0.1.2) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30.0->streamlit>=1.12.0->voicefixer==0.1.2) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->voicefixer==0.1.2) (0.30.0)
# Downloading pedalboard-0.9.23-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 90.4 MB/s eta 0:00:00
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 127.8 MB/s eta 0:00:00
# Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 123.9 MB/s eta 0:00:00
# Building wheels for collected packages: voicefixer, progressbar
#   Building wheel for voicefixer (setup.py) ... done
#   Created wheel for voicefixer: filename=voicefixer-0.1.2-py3-none-any.whl size=51867 sha256=49a821b9d314826f4071d51dfe92501ddd07ef6fae17b82adc7f82c36910489a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3jly5h1e/wheels/14/b9/4b/dfefbadcd7953c01e4b380e8b987d6cc536ef5631dbfafdd88
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12065 sha256=87991f1803db4fe54138da07f3aced150de20817f1c271cac7fe69ab60067d8a
#   Stored in directory: /root/.cache/pip/wheels/a5/4d/c7/f3cf0f75c746c219090060131fe00f1523cc2c5484991f4030
# Successfully built voicefixer progressbar
# Installing collected packages: progressbar, pedalboard, pydeck, torchlibrosa, streamlit, voicefixer
# Successfully installed pedalboard-0.9.23 progressbar-2.5 pydeck-0.9.2 streamlit-1.58.0 torchlibrosa-0.1.0 voicefixer-0.1.2

# %%
# !sudo apt-get update && sudo apt-get install -y ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,703 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,129 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,299 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,974 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,042 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,607 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,400 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,313 kB]
# Fetched 42.2 MB in 4s (9,604 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 64 not upgraded.

# %%
import os
import torch
import librosa
import soundfile as sf
from voicefixer import VoiceFixer
from pedalboard import Pedalboard, HighpassFilter, PeakFilter, Compressor, Gain

# Check if GPU acceleration is available for the AI engine
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using processing unit: {device.upper()}")

print("Initializing VoiceFixer AI Engine...")
vf = VoiceFixer()
print("AI Engine ready.")
# Out:
# Using processing unit: CUDA
# Initializing VoiceFixer AI Engine...
# AI Engine ready.

# %%
# 1. Define the file path variables explicitly in this block
input_mpeg_path = "audiofile.mpeg"
converted_wav_path = "converted_input.wav"
ai_restored_path = "ai_restored_output.wav"

print(f"Step 1A: Converting {input_mpeg_path} to standardized PCM WAV...")
try:
    audio_signal, sample_rate = librosa.load(input_mpeg_path, sr=44100)
    sf.write(converted_wav_path, audio_signal, sample_rate)
    print("MPEG conversion successful.")
except Exception as e:
    print(f"Error converting your MPEG file: {e}")

print("\nStep 1B: Running AI Speech Restoration...")
vf.restore(
    input=converted_wav_path,
    output=ai_restored_path,
    cuda=torch.cuda.is_available(),
    mode=0  # If speech sounds a little muffled, you can try changing this to 1 later
)

print(f"AI Restoration complete. Saved to variable variable path: {ai_restored_path}")
# Out:
# Step 1A: Converting audiofile.mpeg to standardized PCM WAV...
# MPEG conversion successful.
#
# Step 1B: Running AI Speech Restoration...
# AI Restoration complete. Saved to variable variable path: ai_restored_output.wav

# %%
final_output_path = "crystal_clear_speech.wav"

print("Step 2A: Configuring DSP Mastering Chain...")
dsp_board = Pedalboard([
    HighpassFilter(cutoff_frequency_hz=85.0),
    PeakFilter(cutoff_frequency_hz=6000.0, gain_db=6.0, q=0.7), # Adds crisp sharpness
    Compressor(threshold_db=-14.0, ratio=3.0, attack_ms=10.0, release_ms=100.0),
    Gain(gain_db=2.0)
])

print("Step 2B: Rendering final intelligible audio file...")
# This will now successfully find 'ai_restored_path' because Step 2 was run
audio_data, sample_rate = librosa.load(ai_restored_path, sr=None)
mastered_audio = dsp_board(audio_data, sample_rate)
sf.write(final_output_path, mastered_audio, sample_rate)

print("\n--- PROCESS COMPLETED ---")
print(f"Your final intelligible audio file is ready at: {final_output_path}")
# Out:
# Step 2A: Configuring DSP Mastering Chain...
# Step 2B: Rendering final intelligible audio file...
#
# --- PROCESS COMPLETED ---
# Your final intelligible audio file is ready at: crystal_clear_speech.wav
